# %%
import os
import langchain
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
langchain.__version__
# Out:
# '0.3.27'

# %%
loader = TextLoader("data/books/le_petit_prince.txt")
docs = loader.load()
docs[0].page_content[:500]
# Out:
# "LE PETIT PRINCE\n\nAntoine De Saint-Exupery \n\nDEDICACE\nA LÃ‰ON WERTH.\n\nJe demande pardon aux enfants d'avoir dÃ©diÃ© ce livre Ã\xa0 une grande personne. J'ai une excuse sÃ©rieuse: cette grande personne est le meilleur ami que j'ai au monde. J'ai une autre excuse: cette grande personne peut tout comprendre, mÃªme les livres pour enfants. J'ai une troisiÃ¨me excuse: cette grande personne habite la France oÃ¹ elle a faim et froid. Elle a bien besoin d'Ãªtre consolÃ©e. Si toutes ces excuses ne suffisent "

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)
len(all_splits)
# Out:
# 110

# %%
all_splits[1]
# Out:
# Document(metadata={'source': 'data/books/le_petit_prince.txt', 'start_index': 725}, page_content='A LÃ‰ON WERTH\nQUAND IL Ã‰TAIT PETIT GARÃ‡ON\n\nPREMIER CHAPITRE\nLorsque j\'avais six ans j\'ai vu, une fois, une magnifique image, dans un livre sur la forÃªt vierge qui s\'appelait "Histoires VÃ©cues". Ã‡a reprÃ©sentait un serpent boa qui avalait un fauve. VoilÃ\xa0 la copie du dessin.\n\n\n\n\nOn disait dans le livre: "Les serpents boas avalent leur proie tout entiÃ¨re, sans la mÃ¢cher. Ensuite ils ne peuvent plus bouger et ils dorment pendant les six mois de leur digestion".\n\nJ\'ai alors beaucoup rÃ©flÃ©chi sur les aventures de la jungle et, Ã\xa0 mon tour, j\'ai rÃ©ussi, avec un crayon de couleur, Ã\xa0 tracer mon premier dessin. Mon dessin numÃ©ro 1. Il Ã©tait comme Ã§a:\n\n\n\nJ\'ai montrÃ© mon chef-d\'oeuvre aux grandes personnes et je leur ai demandÃ© si mon dessin leur faisait peur.\n\nElles m\'ont rÃ©pondu: "Pourquoi un chapeau ferait-il peur?"')

# %%
all_splits[2].metadata
# Out:
# {'source': 'data/books/le_petit_prince.txt', 'start_index': 1392}

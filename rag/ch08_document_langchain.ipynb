# %%
import os
import langchain
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
langchain.__version__
# Out:
# '0.3.27'

# %%
docs = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
]
docs
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=20, chunk_overlap=10, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)
all_splits
# Out:
# [Document(metadata={'source': 'mammal-pets-doc', 'start_index': 0}, page_content='Dogs are great'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 9}, page_content='great companions,'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 27}, page_content='known for their'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 33}, page_content='for their loyalty'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 43}, page_content='loyalty and'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 51}, page_content='and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 0}, page_content='Cats are independent'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 21}, page_content='pets that often'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 31}, page_content='often enjoy their'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 43}, page_content='their own space.')]

# %%
for split in all_splits:
    split.metadata["toto"]="titi"
all_splits
# Out:
# [Document(metadata={'source': 'mammal-pets-doc', 'start_index': 0, 'toto': 'titi'}, page_content='Dogs are great'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 15, 'toto': 'titi'}, page_content='companions, known'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 33, 'toto': 'titi'}, page_content='for their loyalty'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 51, 'toto': 'titi'}, page_content='and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 0, 'toto': 'titi'}, page_content='Cats are independent'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 21, 'toto': 'titi'}, page_content='pets that often'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 37, 'toto': 'titi'}, page_content='enjoy their own'),
#  Document(metadata={'source': 'mammal-pets-doc', 'start_index': 49, 'toto': 'titi'}, page_content='own space.')]
